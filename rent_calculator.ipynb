# %% [markdown]
# <a href="https://colab.research.google.com/github/codejoker197/House-Price-Prediction-using-Linear-Regression/blob/main/rent_calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Input we need from the user
# Total flat rent
# Total food ordered for snacking and grocery
# Electricity bill
# People living in flat/hostel/room

#output
#Total amount to pay

rent = int(input("Enter your flat rent :-"))
food_Grocery = int(input("Enter the amount of food and grocery ordered:-"))
electricity_bill = int(input("Enter the total of electricity bill :- "))
people = int(input("Enter the number of people in living hostel or room :-"))

output = (rent + food_Grocery + electricity_bill) // people

print("Each person will pay = ",output)
# Out:
# Enter your flat rent :-20000
# Enter the amount of food and grocery ordered:-5000
# Enter the total of electricity bill :- 3500
# Enter the number of people in living hostel or room :-5
# Each person will pay =  5700
